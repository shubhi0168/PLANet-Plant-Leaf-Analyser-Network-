# %%
from scipy.signal import convolve2d

# %%
import tensorflow
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import tensorflow.keras.layers as Conv2d

# %%
image_path = "D:/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/test/test/3.jfif"

# %%
p = img.imread(image_path)

# %%
p=  p /255

# %%
kernerl = np.array([
    [-1,0,1],
    [-1,0,1],
    [-1,0,1]
])

# %%
kernerl2 = np.array([
    [-1,-1,-1],
    [0,0,0],
    [1,1,1]
])

# %%
kernerl3 = np.array([
    [0,-1,0],
    [-1,5,-1],
    [0,-1,0]

    
])

# %%
temp1 = convolve2d(p[:,:,0],kernerl,mode='same')
temp2 = convolve2d(p[:,:,1],kernerl2,mode='same')
temp5 = convolve2d(p[:,:,1],kernerl2,mode='same')
temp3 = np.sqrt(temp1**2 + temp2**2)
temp4 = np.arctan(temp1/temp2+p[:,:,0])
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
fig=plt.figure(figsize=(32,32))
fig.add_subplot(3, 2, 1)
plt.imshow(p,cmap='gray')
fig.add_subplot(3, 2, 2)
plt.imshow(temp3+p[:,:,0],cmap='gray')
fig.add_subplot(3, 2, 3)
plt.imshow(temp4,cmap='gray')
fig.add_subplot(3, 2, 4)
plt.imshow(temp5,cmap='gray')
fig.add_subplot(3, 2, 5)
plt.imshow(temp5+p[:,:,0])
fig.add_subplot(3, 2, 6)
plt.imshow(temp5)
plt.show()

# %%
from skimage.color import gray2rgb
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
gray=rgb2gray(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a572da5e34cf> in <module>
# ----> 1 gray=rgb2gray(p)
#
# NameError: name 'rgb2gray' is not defined

# %%
temp3-temp3%2

# %%
gray = rgb2gray(p)

# defining the sobel filters
sobel_horizontal = np.array([np.array([1, 2, 1]), np.array([0, 0, 0]), np.array([-1, -2, -1])])
print(sobel_horizontal, 'is a kernel for detecting horizontal edges')
 
sobel_vertical = np.array([np.array([-1, 0, 1]), np.array([-2, 0, 2]), np.array([-1, 0, 1])])
print(sobel_vertical, 'is a kernel for detecting vertical edges')
kernel_laplace = np.array([np.array([1, 1, 1]), np.array([1, -8, 1]), np.array([1, 1, 1])])
print(kernel_laplace, 'is a laplacian kernel')

# %%
out_h = ndimage.convolve(gray, sobel_horizontal, mode='reflect')
out_v = ndimage.convolve(gray, sobel_vertical, mode='reflect')
out_l = ndimage.convolve(gray, kernel_laplace, mode='reflect')

# %%
plt.imshow(out_l, cmap='gray')

# %%
pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
pic_n.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-393-43e7f1ebcf53> in <module>
# ----> 1 pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
#       2 pic_n.shape
#
# IndexError: tuple index out of range

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(pic_n/255)
pic2show = kmeans.cluster_centers_[kmeans.labels_]

# %%
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
plt.imshow(cluster_pic)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-424-da6eaa7ac553> in <module>
# ----> 1 cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
#       2 plt.imshow(cluster_pic)
#
# IndexError: tuple index out of range

# %%
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Reshape,Dropout,MaxPooling2D,Conv2D,UpSampling2D,Dense,Activation

# %%
model = Sequential()
model.add(Conv2D(3, (3,3),padding='same', input_shape=(256, 256, 3)))
# summarize the model
model.add(Conv2D(3, (3,3),padding='same', input_shape=(256, 256, 3)))
model.summary()
# Out:
# Model: "sequential_46"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_98 (Conv2D)           (None, 256, 256, 3)       84
# ...
# Total params: 84
# Trainable params: 84
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np

import cv2
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
img_building = cv2.imread(r"D:\PlantVillage-Dataset\raw\color\Peach___Bacterial_spot\2bab9e1e-45b1-40f3-96c6-1c0b832c174e___Rutg._Bact.S 1571.JPG")
img_building = cv2.cvtColor(img_building, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_building)

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D,BatchNormalization
# from tensorflow.keras.layers.normalization import BatchNormalization
import numpy as np

model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(256,256,3), kernel_size=(11,11), strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# Output Layer
model.add(Dense(29))
model.add(Activation('softmax'))
model.summary()

model.compile(loss=tensorflow.keras.losses.categorical_crossentropy, optimizer='adam', metrics=["accuracy"])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_25 (Conv2D)           (None, 62, 62, 96)        34944
# _________________________________________________________________
# activation_39 (Activation)   (None, 62, 62, 96)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 31, 31, 96)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 21, 21, 256)       2973952
# _________________________________________________________________
# activation_40 (Activation)   (None, 21, 21, 256)       0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 8, 8, 384)         885120
# ...

# %%
import tensorflow.keras
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3

#Load the VGG model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
#Load the VGG model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))

print(base_model.summary())

    # Freeze the layers 
# for layer in base_model.layers:
#     layer.trainable = True
 
# # Create the model
model = keras.models.Sequential()

# # Add the vgg convolutional base model
model.add(base_model)
 
# # Add new layers
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(num_class, activation='softmax')) 
 
# # Show a summary of the model. Check the number of trainable parameters    
print(model.summary())
model.compile(loss='categorical_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 127, 127, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 127, 127, 32) 96          conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 127, 127, 32) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# ...

# %%
train_datagen = ImageDataGenerator(validation_split=0.2,
                                   rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
                        directory=train_path,
                        
                        target_size=(image_size,image_size),
                        batch_size=batch_size,
                        class_mode='categorical',
                        color_mode='rgb',
                        subset="training",
                        shuffle=True)

validation_generator = train_datagen.flow_from_directory(
                        directory=train_path,
                        target_size=(image_size,image_size),
                        batch_size=batch_size,
                        class_mode='categorical',
                        color_mode='rgb',
                        subset="validation",
                        shuffle=True)
# Out:
# Found 26003 images belonging to 29 classes.
# Found 6488 images belonging to 29 classes.

# %%
train_path = 'D:\plantvillage_deeplearning_paper_dataset\plantvillage_deeplearning_paper_dataset\color'

# %%
batch_size = 32
image_size = 256
num_class = 29

# %%
model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 40)
# Out:
# Epoch 1/40
# 812/812 [==============================] - 992s 1s/step - loss: 3.2574 - accuracy: 0.0690 - val_loss: 3.2547 - val_accuracy: 0.0650
# Epoch 2/40
# 812/812 [==============================] - 566s 698ms/step - loss: 3.2548 - accuracy: 0.0692 - val_loss: 3.2500 - val_accuracy: 0.0709
# Epoch 3/40
# 812/812 [==============================] - 481s 593ms/step - loss: 3.2525 - accuracy: 0.0692 - val_loss: 3.2501 - val_accuracy: 0.0709
# Epoch 4/40
# 812/812 [==============================] - 556s 685ms/step - loss: 3.2516 - accuracy: 0.0684 - val_loss: 3.2493 - val_accuracy: 0.0709
# Epoch 5/40
# 812/812 [==============================] - 484s 596ms/step - loss: 3.2513 - accuracy: 0.0693 - val_loss: 3.2494 - val_accuracy: 0.0709
# Epoch 6/40
# 240/812 [=======>......................] - ETA: 4:06 - loss: 3.2452 - accuracy: 0.0742
# ---------------------------------------------------------------------------
# ...
